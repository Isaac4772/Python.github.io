# %%
temps = {'Osio':13, 'London':14.7,"Paris":15.2}

# %%
type(temps)
# Out:
# dict

# %%
print("Temperature in Osio is:",temps['Osio'])
# Out:
# Temperature in Osio is: 13

# %%
print("Temperature in Osio is:",temps['London'])
# Out:
# Temperature in Osio is: 14.7

# %%
temps.keys()
# Out:
# dict_keys(['Osio', 'London', 'Paris'])

# %%
temps.values()
# Out:
# dict_values([13, 14.7, 15.2])

# %%
temps
# Out:
# {'Osio': 13, 'London': 14.7, 'Paris': 15.2}

# %%
temps['Osio'] = 15.5

# %%
temps
# Out:
# {'Osio': 15.5, 'London': 14.7, 'Paris': 15.2, 'Oslo': 15.5}

# %%
temps['Yangon'] = 30

# %%
del temps['Yangon']

# %%
temps
# Out:
# {'Osio': 15.5, 'London': 14.7, 'Paris': 15.2, 'Oslo': 15.5}

# %%
for key in temps:
    print(temps[key])
# Out:
# 15.5
# 14.7
# 15.2
# 15.5

# %%
sum = 0
for city in temps:
    value = float(temps[city])
    sum += temps[city]
print('Total Temperature',sum)
# Out:
# Total Temperature 60.9

# %%
for city in sorted(temps):
    print("%s has %.2f degrees"%(city,temps[city]))
# Out:
# London has 14.70 degrees
# Osio has 15.50 degrees
# Oslo has 15.50 degrees
# Paris has 15.20 degrees

# %%
if 'Oslo' in temps:
    print('Oslo', temps['Oslo'])
else:
    print('Oslo is not in the dictionary')
# Out:
# Oslo 15.5

# %%
t1 = temps
print(t1)
# Out:
# {'Osio': 15.5, 'London': 14.7, 'Paris': 15.2, 'Oslo': 15.5}

# %%
t1['Yangon'] = 30

# %%
t2 = temps.copy()

# %%
t2
# Out:
# {'Osio': 15.5, 'London': 14.7, 'Paris': 15.2, 'Oslo': 15.5, 'Yangon': 30}

# %% [markdown]
# # Pollynomial Respreseted by Dictionries

# %%
p = {0: -1, 2: 1, 7: 3}
def eval_poly_dict(poly,x):
    sum = 0.0
    for power in poly:
        sum += poly[power]*x**power
    return sum

# %%
print(eval_poly_dict(p,2))
# Out:
# 387.0

# %%
def eval_poly_dict2(poly,x):
    return sum(poly[power]*x**power for power in poly)

# %%
poly = [-1,0,1,0,0,0,0,3]

# %%
print(eval_poly_dict2(poly,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-937e9aad9430> in <module>
# ----> 1 print(eval_poly_dict2(poly,2))
#
# <ipython-input-45-7bcd1ccd252a> in eval_poly_dict2(poly, x)
#       1 def eval_poly_dict2(poly,x):
# ----> 2     return sum(poly[power]*x**power for power in poly)
#
# TypeError: 'float' object is not callable

# %%
##Read file Data

# %%
file = open('deg2.dat', 'w')
file.write("""Oslo: 21.8
London: 18.1
Berlin: 19
Paris: 23
Rome: 26
Helsinki: 17.8
""")
file.close()

# %%
infile = open('deg2.dat', 'r')
temps = {}
for line in infile.readlines():
    c,t = line.split()
    c = c[:-1]
    temps[c] = float(t)
infile.close()

# %%
temps
# Out:
# {'Oslo': 21.8,
#  'London': 18.1,
#  'Berlin': 19.0,
#  'Paris': 23.0,
#  'Rome': 26.0,
#  'Helsinki': 17.8}

# %%
data = {'A':{1:11.7,2:9.2}}

# %%
data
# Out:
# {'A': {1: 11.7, 2: 9.2}}

# %%
data['A'][2]
# Out:
# 9.2

# %%
file = open('table.dat', 'w')
file.write("""   A     B     C     D
1 11.7  0.035  2017  99.1
2 9.2   0.037  2019  101.2
3 12.2  no     no    105.2
4 10.1  0.031  no    102.1
5 9.1   0.033  2009  103.3
6 8.7   0.036  2015  101.9
""")
file.close()

# %%
infile = open('table.dat','r')
lines = infile.readlines()
infile.close()
data = {}
first_line = lines[0]
properties = first_line.split()
for p in properties:
    data[p] = {}
for line in lines[]
# Out:
#   File "<ipython-input-94-8be66c8271fa>", line 9
#     for line in lines[]
#                       ^
# SyntaxError: invalid syntax

# %%
lines
# Out:
# ['   A     B     C     D\n',
#  '1 11.7  0.035  2017  99.1\n',
#  '2 9.2   0.037  2019  101.2\n',
#  '3 12.2  no     no    105.2\n',
#  '4 10.1  0.031  no    102.1\n',
#  '5 9.1   0.033  2009  103.3\n',
#  '6 8.7   0.036  2015  101.9\n']

# %%
print(properties)
# Out:
# ['H']

# %% [markdown]
# # Download data from the web and visualize

# %%
from datetime import datetime
def read_line(filename):
    infile = open(filename, 'r')
    lines = infile.readlines()
    infile.close()
    dates = []
    prices = []
    for line in lines[16:]:
        words = line.split(',')
        dates.append(words[0])
        prices.append(float(words[-2]))
    dates.reverse()
    prices.reverse()
    
    datefmt = "%Y-%m-%d"
    dates = [datetime.strptime(_date, datefmt).date() for _date in dates]
    price = np.array(prices)
    return dates,prices
# Out:
#   File "<ipython-input-61-c9e1cc31c484>", line 1
#     from datetime import datetime
#                                  ^
# SyntaxError: invalid syntax

# %%
import glob
import numpy as np
dates = {}; prices = {}
filenames = glob.glob("csv files/*.csv")
companies = []
for filename in filenames:
    company = filename[10:15]
    companies.append(company)
    d, p = read_line(filename)
    dates[company] = d
    prices[company] = p

# %%
dates, prices
# Out:
# ({'APPLE': [datetime.date(2021, 11, 5),
#    datetime.date(2021, 11, 4),
#    datetime.date(2021, 11, 3),
#    datetime.date(2021, 11, 2),
#    datetime.date(2021, 11, 1),
#    datetime.date(2021, 10, 29),
#    datetime.date(2021, 10, 28),
#    datetime.date(2021, 10, 27),
#    datetime.date(2021, 10, 26),
#    datetime.date(2021, 10, 25),
#    datetime.date(2021, 10, 22),
#    datetime.date(2021, 10, 21),
#    datetime.date(2021, 10, 20),
#    datetime.date(2021, 10, 19),
#    datetime.date(2021, 10, 18),
#    datetime.date(2021, 10, 15),
#    datetime.date(2021, 10, 14),
#    datetime.date(2021, 10, 13),
#    datetime.date(2021, 10, 12),
#    datetime.date(2021, 10, 11),
#    datetime.date(2021, 10, 8),
#    datetime.date(2021, 10, 7),
#    datetime.date(2021, 10, 6),
#    datetime.date(2021, 10, 5),
#    datetime.date(2021, 10, 4),
#    datetime.date(2021, 10, 1),
#    datetime.date(2021, 9, 30),
#    datetime.date(2021, 9, 29),
#    datetime.date(2021, 9, 28),
# ...

# %%
first_months = [dates[company][0] for company in dates]
normalize_date = max(first_months)
for company in dates:
    index = dates[company].index(normalize_date)
   

import matplotlib.pyplot as plt
import matplotlib.dates as mdate

fig, ax = plt.subplots()
legends = []
for company in prices:
    ax.plot_date( dates[company], np.log(prices[company]), '-' , label=company)
    legends.append(company)
ax.legend(legends, loc = 'upper left')
ax.set_ylabel('logarithm of normalized value')

ax.xaxis.set_major_formatter(mdate.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_minor_locator(mdate.MonthLocator(1))
ax.autoscale_view()
fig.autofmt_xdate()
plt.savefig("tmp.pdf")
plt.savefig("tmp.png")
plt.show()

# %%
first_months

# %%
file = open('xy.dat','w')
file.write("""(1,3,0) (-1,2) (3,01,5)
(0,1) (1,0) (1,1)
(0,-0.01) (10.5, 1) (2.5, -2.5)""")
file.close()

# %%
infile = open('xy.dat','r')
lines = infile.readlines()
infile.close()

# %%
lines
# Out:
# ['(1,3,0) (-1,2) (3,01,5)\n',
#  '(0,1) (1,0) (1,1)\n',
#  '(0,-0.01) (10.5, 1) (2.5, -2.5)']

# %%
pairs = []
for line in lines:
    words = line.split()
    for word in words:
        word = word[1:-1]
        n1, n2 = word.split(',')
        pair = (float(n1), float(n2))
        pairs.append(pair)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-650593931416> in <module>
#       4     for word in words:
#       5         word = word[1:-1]
# ----> 6         n1, n2 = word.split(',')
#       7         pair = (float(n1), float(n2))
#       8         pairs.append(pair)
#
# ValueError: too many values to unpack (expected 2)

# %%
pairs
# Out:
# []

# %% [markdown]
# # Reading the climate data

# %%
local_file = 'oxforddata.txt'
infile = open(local_file , 'r')
data = {}

data['place'] = infile.readline().strip()
data['location'] = infile.readline().strip()
for i in range(5):
    infile.readline()
data['data'] = {}

lines  = infile.readlines()

for line in lines:
    columns = line.split()
    print(columns)
    year = int(columns[0])
    month = int(columns[1])
    
    if columns[-1] == "Provisional":
        del columns[-1]
        
    for i in range(2, len(columns)):
        if columns[i] == "---":
            columns[i] = None
        elif columns[i][-1] == "*" or columns[i][-1] == '#':
            columns[i] = float(columns[i][:-1])
        else:
            columns[i] = float(columns[i])
    
    tmax, tmin, air_frost, rain, sun = columns[2:]
    print(tmax, tmin, air_frost, rain, sun)
    
    if not year in data['data']:
        data['data'][year] = {}
    for m in range(1,month+1):
        data['data'][year][month] = {'tmax' : tmax, 'tmin': tmin, 'air forst': air_frost, 'sum': sun}
# Out:
# ['1853', '1', '8.4', '2.7', '4', '62.8', '---']
# 8.4 2.7 4.0 62.8 None
# ['1853', '2', '3.2', '-1.8', '19', '29.3', '---']
# 3.2 -1.8 19.0 29.3 None
# ['1853', '3', '7.7', '-0.6', '20', '25.9', '---']
# 7.7 -0.6 20.0 25.9 None
# ['1853', '4', '12.6', '4.5', '0', '60.1', '---']
# 12.6 4.5 0.0 60.1 None
# ['1853', '5', '16.8', '6.1', '0', '59.5', '---']
# 16.8 6.1 0.0 59.5 None
# ['1853', '6', '20.1', '10.7', '0', '82.0', '---']
# 20.1 10.7 0.0 82.0 None
# ['1853', '7', '21.2', '12.2', '0', '86.2', '---']
# 21.2 12.2 0.0 86.2 None
# ['1853', '8', '20.2', '10.8', '0', '72.3', '---']
# 20.2 10.8 0.0 72.3 None
# ['1853', '9', '17.3', '8.4', '0', '51.3', '---']
# 17.3 8.4 0.0 51.3 None
# ['1853', '10', '13.9', '7.4', '0', '102.3', '---']
# 13.9 7.4 0.0 102.3 None
# ['1853', '11', '8.7', '2.3', '10', '49.6', '---']
# 8.7 2.3 10.0 49.6 None
# ['1853', '12', '3.7', '-1.3', '19', '10.7', '---']
# 3.7 -1.3 19.0 10.7 None
# ['1854', '1', '6.7', '1.5', '11', '54.5', '---']
# ...

# %%
data['data'][1854]
# Out:
# {1: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  2: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  3: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  4: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  5: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  6: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  7: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  8: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  9: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  10: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  11: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None},
#  12: {'tmax': 8.3, 'tmin': 2.1, 'air forst': 8.0, 'sum': None}}
